# %% [markdown]
# # 1. Hyperparameter Tuning

# %% [markdown]
# ## 1) 베이지안 최적화

# %%
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading bayesian_optimization-1.4.3-py3-none-any.whl.metadata (543 bytes)
# Collecting numpy>=1.9.0 (from bayesian-optimization)
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting scipy>=1.0.0 (from bayesian-optimization)
#   Using cached scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
# Collecting scikit-learn>=0.18.0 (from bayesian-optimization)
#   Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting colorama>=0.4.6 (from bayesian-optimization)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting joblib>=1.1.1 (from scikit-learn>=0.18.0->bayesian-optimization)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=0.18.0->bayesian-optimization)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading bayesian_optimization-1.4.3-py3-none-any.whl (18 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 10.4 MB/s eta 0:00:00a 0:00:01
# Using cached scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, colorama, scipy, scikit-learn, bayesian-optimization
# Successfully installed bayesian-optimization-1.4.3 colorama-0.4.6 joblib-1.4.2 numpy-1.24.4 scikit-learn-1.3.2 scipy-1.10.1 threadpoolctl-3.5.0

# %%
1
# Out:
# 1

# %%
from sklearn.metrics import f1_score
from xgboost import XGBClassifier

# 베이지안 최적화가 주어진 하이퍼 파라미터로 학습 및 평가를 돌려보는 함수

# 탐색 대상 함수 (XGBClassifier)
def XGB_cv(max_depth,learning_rate, n_estimators):
    # 모델 정의
    model = XGBClassifier(max_depth=int(max_depth),
                            learning_rate=learning_rate,
                            n_estimators=int(n_estimators)
                            )
    # 모델 훈련
    model.fit(X_train, y_train)
    # 예측값 출력
    y_pred= model.predict(X_test)
    f1 = f1_score(y_test, y_pred)
    # 오차 최적화로 사용할 metric 반환 (베이지안은 이것을 성능수치로 받아들이게됨)
    return f1

# %%
#  bayesian-optimization 라이브러리의 BayesianOptimization 클래스 import
from bayes_opt import BayesianOptimization
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

# make_moons 분류 데이터 500 x 2 피처 데이터
X, y = make_moons(n_samples=500, noise=0.30, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# 실험해보고자하는 hyperparameter 집합
# max_depth(int, default: 3): 기본 학습자를 위한 최대 트리 깊이
# learning_rate(float, default: 0.1) : Boosting 학습률
# n_estimators(int, default: 100) : fit하기 위한 Boosted tree의 수

pbounds = {'max_depth': (3, 7),   # 3~7
            'learning_rate': (0.001, 0.2), # 0.001 ~ 0.2
            'n_estimators': (5000, 10000) # 5000~10000
            }

# Bayesian optimization 객체 생성
# f : 탐색 대상 함수, pbounds : hyperparameter 집합
# verbose = 2 항상 출력, verbose = 1 최댓값일 때 출력, verbose = 0 출력 안함
bo=BayesianOptimization(f=XGB_cv, pbounds=pbounds, verbose=2, random_state=1 )

# 메소드를 이용해 최대화 과정 수행
# init_points :  초기 Random Search 갯수
# n_iter : 반복 횟수 (몇개의 입력값-함숫값 점들을 확인할지! 많을 수록 정확한 값을 얻을 수 있다.)
# acq : Acquisition Function들 중 Expected Improvement(EI) 를 사용
# xi : exploration 강도 (기본값은 0.0)
bo.maximize(init_points=2, n_iter=10)


# ‘iter’는 반복 회차, ‘target’은 목적 함수의 값, 나머지는 입력값을 나타냄.
# 현재 회차 이전까지 조사된 함숫값들과 비교하여, 현재 회차에 최댓값이 얻어진 경우,
# bayesian-optimization 라이브러리는 이를 자동으로 다른 색 글자로 표시하는 것을 확인.

# 찾은 파라미터 값 확인
print(bo.max)

# %%
model = XGBClassifier(max_depth=int(6.054141795109241),
                            learning_rate=0.06517207912793385,
                            n_estimators=int(9284.808327884073)
                            )
# 모델 훈련
model.fit(X_train, y_train)
# 예측값 출력
y_pred= model.predict(X_test)
f1 = f1_score(y_test, y_pred)
f1

# %% [markdown]
# ## 2) Hyperparameter Tuning - optuna

# %%
# !pip install optuna

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import xgboost
import optuna

# %%
X, y = make_moons(n_samples=500, noise=0.30, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
def objective(trial): # 옵튜나 객체
    param = {
        'max_depth': trial.suggest_int('max_depth', 1, 10), #옵튜나한테 int 타입을 제안한다 maxdepth 1 ~ 10 카운팅 값으로 뽑아낸다.
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 1.0), # 옵튜나한테 float타입으로 제안한다.
        'n_estimators': trial.suggest_int('n_estimators', 50, 1000),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0.01, 1.0),
        'subsample': trial.suggest_float('subsample', 0.01, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.01, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.01, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.01, 1.0),
        'random_state': trial.suggest_int('random_state', 1, 1000)
    }
    model = XGBClassifier(**param)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return f1_score(y_test, y_pred)

# %%
# Create the study
study = optuna.create_study(direction='maximize') # maximize
              # 탐색함수, 시도할 횟수
study.optimize(objective, n_trials=100)

# %%
# best parameters
print('Best parameters', study.best_params)

# %%
model = XGBClassifier(**study.best_params) # 최적의 하이퍼 파라미터
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('f1_score: ', f1_score(y_test, y_pred))

# %% [markdown]
# # 2. AutoML

# %% [markdown]
# ## 1) pycaret

# %%
# !pip install pycaret

# %%
#pycaret에서 제공하는 'juice' 데이터
from pycaret.datasets import get_data
data = get_data('juice')
#data.info()
print(data)
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 0   0.000000   0.000000           0.24      1
# 1   0.150754   0.000000           0.24      1
# 2   0.000000   0.091398           0.23      1
# 3   0.000000   0.000000           0.00      1
# 4   0.000000   0.000000           0.00      0
#         Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  \
# 0        1       CH             237        1     1.75     1.99    0.00
# 1        2       CH             239        1     1.75     1.99    0.00
# 2        3       CH             245        1     1.86     2.09    0.17
# 3        4       MM             227        1     1.69     1.69    0.00
# 4        5       CH             228        7     1.69     1.69    0.00
# ...    ...      ...             ...      ...      ...      ...     ...
# 1065  1066       CH             252        7     1.86     2.09    0.10
# 1066  1067       CH             256        7     1.86     2.18    0.00
# 1067  1068       MM             257        7     1.86     2.18    0.00
# 1068  1069       CH             261        7     1.86     2.13    0.00
# 1069  1070       CH             270        1     1.86     2.18    0.00
#
#       DiscMM  SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  \
# 0       0.00          0          0  0.500000         1.99         1.75
# 1       0.30          0          1  0.600000         1.69         1.75
# 2       0.00          0          0  0.680000         2.09         1.69
# 3       0.00          0          0  0.400000         1.69         1.69
# 4       0.00          0          0  0.956535         1.69         1.69
# ...      ...        ...        ...       ...          ...          ...
# 1065    0.00          0          0  0.587822         2.09         1.76
# 1066    0.00          0          0  0.670258         2.18         1.86
# 1067    0.00          0          0  0.736206         2.18         1.86
# 1068    0.24          0          0  0.588965         1.89         1.86
# 1069    0.00          0          0  0.671172         2.18         1.86
#
#       PriceDiff Store7  PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 0          0.24     No   0.000000   0.000000           0.24      1
# 1         -0.06     No   0.150754   0.000000           0.24      1
# 2          0.40     No   0.000000   0.091398           0.23      1
# 3          0.00     No   0.000000   0.000000           0.00      1
# 4          0.00    Yes   0.000000   0.000000           0.00      0
# ...         ...    ...        ...        ...            ...    ...
# 1065       0.33    Yes   0.000000   0.053763           0.23      0
# 1066       0.32    Yes   0.000000   0.000000           0.32      0
# 1067       0.32    Yes   0.000000   0.000000           0.32      0
# 1068       0.03    Yes   0.112676   0.000000           0.27      0
# 1069       0.32     No   0.000000   0.000000           0.32      1
#
# [1070 rows x 19 columns]

# %%
from pycaret.classification import *  # setup, compare_models
setup_clf = setup(data=data, target='Purchase')
class_top = compare_models()
class_top
# Out:
# <style type="text/css">
# #T_9e6be_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9e6be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e6be_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9e6be_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e6be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e6be_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9e6be_row0_col1" class="data row0 col1" >1151</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e6be_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9e6be_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9e6be_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9e6be_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9e6be_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_9e6be_row3_col1" class="data row3 col1" >CH: 0, MM: 1</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9e6be_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_9e6be_row4_col1" class="data row4 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9e6be_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_9e6be_row5_col1" class="data row5 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9e6be_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_9e6be_row6_col1" class="data row6 col1" >(749, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9e6be_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_9e6be_row7_col1" class="data row7 col1" >(321, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9e6be_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_9e6be_row8_col1" class="data row8 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9e6be_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_9e6be_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9e6be_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_9e6be_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9e6be_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_9e6be_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9e6be_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_9e6be_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9e6be_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_9e6be_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9e6be_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_9e6be_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9e6be_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_9e6be_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9e6be_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_9e6be_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9e6be_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_9e6be_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9e6be_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_9e6be_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9e6be_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_9e6be_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9e6be_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_9e6be_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9e6be_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_9e6be_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9e6be_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9e6be_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_9e6be_row22_col1" class="data row22 col1" >9983</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1e0ca th {
#   text-align: left;
# }
# #T_1e0ca_row0_col0, #T_1e0ca_row0_col2, #T_1e0ca_row1_col0, #T_1e0ca_row1_col1, #T_1e0ca_row1_col3, #T_1e0ca_row1_col4, #T_1e0ca_row1_col5, #T_1e0ca_row1_col6, #T_1e0ca_row1_col7, #T_1e0ca_row2_col0, #T_1e0ca_row2_col1, #T_1e0ca_row2_col2, #T_1e0ca_row2_col3, #T_1e0ca_row2_col4, #T_1e0ca_row2_col5, #T_1e0ca_row2_col6, #T_1e0ca_row2_col7, #T_1e0ca_row3_col0, #T_1e0ca_row3_col1, #T_1e0ca_row3_col2, #T_1e0ca_row3_col3, #T_1e0ca_row3_col4, #T_1e0ca_row3_col5, #T_1e0ca_row3_col6, #T_1e0ca_row3_col7, #T_1e0ca_row4_col0, #T_1e0ca_row4_col1, #T_1e0ca_row4_col2, #T_1e0ca_row4_col3, #T_1e0ca_row4_col4, #T_1e0ca_row4_col5, #T_1e0ca_row4_col6, #T_1e0ca_row4_col7, #T_1e0ca_row5_col0, #T_1e0ca_row5_col1, #T_1e0ca_row5_col2, #T_1e0ca_row5_col3, #T_1e0ca_row5_col4, #T_1e0ca_row5_col5, #T_1e0ca_row5_col6, #T_1e0ca_row5_col7, #T_1e0ca_row6_col0, #T_1e0ca_row6_col1, #T_1e0ca_row6_col2, #T_1e0ca_row6_col3, #T_1e0ca_row6_col4, #T_1e0ca_row6_col5, #T_1e0ca_row6_col6, #T_1e0ca_row6_col7, #T_1e0ca_row7_col0, #T_1e0ca_row7_col1, #T_1e0ca_row7_col2, #T_1e0ca_row7_col3, #T_1e0ca_row7_col4, #T_1e0ca_row7_col5, #T_1e0ca_row7_col6, #T_1e0ca_row7_col7, #T_1e0ca_row8_col0, #T_1e0ca_row8_col1, #T_1e0ca_row8_col2, #T_1e0ca_row8_col3, #T_1e0ca_row8_col4, #T_1e0ca_row8_col5, #T_1e0ca_row8_col6, #T_1e0ca_row8_col7, #T_1e0ca_row9_col0, #T_1e0ca_row9_col1, #T_1e0ca_row9_col2, #T_1e0ca_row9_col3, #T_1e0ca_row9_col4, #T_1e0ca_row9_col5, #T_1e0ca_row9_col6, #T_1e0ca_row9_col7, #T_1e0ca_row10_col0, #T_1e0ca_row10_col1, #T_1e0ca_row10_col2, #T_1e0ca_row10_col3, #T_1e0ca_row10_col4, #T_1e0ca_row10_col5, #T_1e0ca_row10_col6, #T_1e0ca_row10_col7, #T_1e0ca_row11_col0, #T_1e0ca_row11_col1, #T_1e0ca_row11_col2, #T_1e0ca_row11_col3, #T_1e0ca_row11_col4, #T_1e0ca_row11_col5, #T_1e0ca_row11_col6, #T_1e0ca_row11_col7, #T_1e0ca_row12_col0, #T_1e0ca_row12_col1, #T_1e0ca_row12_col2, #T_1e0ca_row12_col3, #T_1e0ca_row12_col4, #T_1e0ca_row12_col5, #T_1e0ca_row12_col6, #T_1e0ca_row12_col7, #T_1e0ca_row13_col0, #T_1e0ca_row13_col1, #T_1e0ca_row13_col2, #T_1e0ca_row13_col3, #T_1e0ca_row13_col4, #T_1e0ca_row13_col5, #T_1e0ca_row13_col6, #T_1e0ca_row13_col7 {
#   text-align: left;
# }
# #T_1e0ca_row0_col1, #T_1e0ca_row0_col3, #T_1e0ca_row0_col4, #T_1e0ca_row0_col5, #T_1e0ca_row0_col6, #T_1e0ca_row0_col7, #T_1e0ca_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1e0ca_row0_col8, #T_1e0ca_row1_col8, #T_1e0ca_row2_col8, #T_1e0ca_row3_col8, #T_1e0ca_row4_col8, #T_1e0ca_row5_col8, #T_1e0ca_row6_col8, #T_1e0ca_row7_col8, #T_1e0ca_row8_col8, #T_1e0ca_row9_col8, #T_1e0ca_row10_col8, #T_1e0ca_row11_col8, #T_1e0ca_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1e0ca_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1e0ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e0ca_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1e0ca_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1e0ca_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1e0ca_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1e0ca_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1e0ca_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1e0ca_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1e0ca_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_1e0ca_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e0ca_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_1e0ca_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_1e0ca_row0_col1" class="data row0 col1" >0.8171</td>
#       <td id="T_1e0ca_row0_col2" class="data row0 col2" >0.8837</td>
#       <td id="T_1e0ca_row0_col3" class="data row0 col3" >0.8171</td>
#       <td id="T_1e0ca_row0_col4" class="data row0 col4" >0.8175</td>
#       <td id="T_1e0ca_row0_col5" class="data row0 col5" >0.8164</td>
#       <td id="T_1e0ca_row0_col6" class="data row0 col6" >0.6135</td>
#       <td id="T_1e0ca_row0_col7" class="data row0 col7" >0.6149</td>
#       <td id="T_1e0ca_row0_col8" class="data row0 col8" >0.1340</td>
#     </tr>
#     <tr>
#       <th id="T_1e0ca_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_1e0ca_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_1e0ca_row1_col1" class="data row1 col1" >0.8158</td>
#       <td id="T_1e0ca_row1_col2" class="data row1 col2" >0.8841</td>
#       <td id="T_1e0ca_row1_col3" class="data row1 col3" >0.8158</td>
#       <td id="T_1e0ca_row1_col4" class="data row1 col4" >0.8160</td>
#       <td id="T_1e0ca_row1_col5" class="data row1 col5" >0.8147</td>
#       <td id="T_1e0ca_row1_col6" class="data row1 col6" >0.6095</td>
#       <td id="T_1e0ca_row1_col7" class="data row1 col7" >0.6114</td>
#       <td id="T_1e0ca_row1_col8" class="data row1 col8" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_1e0ca_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_1e0ca_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_1e0ca_row2_col1" class="data row2 col1" >0.8118</td>
#       <td id="T_1e0ca_row2_col2" class="data row2 col2" >0.8825</td>
#       <td id="T_1e0ca_row2_col3" class="data row2 col3" >0.8118</td>
#       <td id="T_1e0ca_row2_col4" class="data row2 col4" >0.8119</td>
#       <td id="T_1e0ca_row2_col5" class="data row2 col5" >0.8102</td>
#       <td id="T_1e0ca_row2_col6" class="data row2 col6" >0.5994</td>
#       <td id="T_1e0ca_row2_col7" class="data row2 col7" >0.6020</td>
#       <td id="T_1e0ca_row2_col8" class="data row2 col8" >1.7970</td>
#     </tr>
#     <tr>
#       <th id="T_1e0ca_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_1e0ca_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_1e0ca_row3_col1" class="data row3 col1" >0.7997</td>
#       <td id="T_1e0ca_row3_col2" class="data row3 col2" >0.8724</td>
#       <td id="T_1e0ca_row3_col3" class="data row3 col3" >0.7997</td>
#       <td id="T_1e0ca_row3_col4" class="data row3 col4" >0.8012</td>
#       <td id="T_1e0ca_row3_col5" class="data row3 col5" >0.7987</td>
#       <td id="T_1e0ca_row3_col6" class="data row3 col6" >0.5762</td>
#       <td id="T_1e0ca_row3_col7" class="data row3 col7" >0.5791</td>
#       <td id="T_1e0ca_row3_col8" class="data row3 col8" >0.3520</td>
#     </tr>
#     <tr>
#       <th id="T_1e0ca_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_1e0ca_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_1e0ca_row4_col1" class="data row4 col1" >0.7971</td>
#       <td id="T_1e0ca_row4_col2" class="data row4 col2" >0.8759</td>
#       <td id="T_1e0ca_row4_col3" class="data row4 col3" >0.7971</td>
#       <td id="T_1e0ca_row4_col4" class="data row4 col4" >0.7985</td>
#       <td id="T_1e0ca_row4_col5" class="data row4 col5" >0.7959</td>
#       <td id="T_1e0ca_row4_col6" class="data row4 col6" >0.5704</td>
#       <td id="T_1e0ca_row4_col7" class="data row4 col7" >0.5733</td>
#       <td id="T_1e0ca_row4_col8" class="data row4 col8" >0.1820</td>
#     </tr>
#     <tr>
#       <th id="T_1e0ca_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_1e0ca_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1e0ca_row5_col1" class="data row5 col1" >0.7957</td>
#       <td id="T_1e0ca_row5_col2" class="data row5 col2" >0.8671</td>
#       <td id="T_1e0ca_row5_col3" class="data row5 col3" >0.7957</td>
#       <td id="T_1e0ca_row5_col4" class="data row5 col4" >0.7960</td>
#       <td id="T_1e0ca_row5_col5" class="data row5 col5" >0.7949</td>
#       <td id="T_1e0ca_row5_col6" class="data row5 col6" >0.5680</td>
#       <td id="T_1e0ca_row5_col7" class="data row5 col7" >0.5695</td>
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, positive=False, random_state=1151, solver='auto',
#                 tol=0.0001)

# %%
# !pip install xgboost

# %%
from pycaret.regression import * # setup, compare_models
from pycaret.datasets import get_data
dataset = get_data('diamond')
exp = setup(dataset, target='Price')
reg_top = compare_models()
reg_top

# %%
# pycaret 버전
import pycaret
print('PyCaret: %s' % pycaret.__version__)

# %%
from pandas import read_csv
# pycaret classification 모듈
from pycaret.classification import setup
# pycaret classification 모델들을 비교하기 위한 모듈
from pycaret.classification import compare_models
# sonar 데이터셋
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv'
# 데이터셋 로드
df = read_csv(url, header=None)
# 컬럼 갯수
n_cols = df.shape[1]
# 컬럼명 String으로 반환
df.columns = [str(i) for i in range(n_cols)]
# 데이터셋 설정
grid = setup(data=df, target=df.columns[-1],  verbose=True)
# 모델 학습
best = compare_models()
# best 모델 확인
print(best)

# %%
from pandas import read_csv
# pycaret classification 모듈
from pycaret.classification import setup
# pycaret classification 모델들을 비교하기 위한 모듈
from pycaret.classification import compare_models

# 데이터셋 로드
df = read_csv("titanic.csv")

# 컬럼 갯수
# n_cols = df.shape[1]

# 컬럼명 String으로 반환
# df.columns = [str(i) for i in range(n_cols)]

# 데이터셋 설정
grid = setup(data=df, target=df.columns[1],  verbose=True)

# 모델 학습
best = compare_models()

# best 모델 확인
print(best)
# Out:
# <style type="text/css">
# #T_64673_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_64673">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64673_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_64673_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64673_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64673_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_64673_row0_col1" class="data row0 col1" >8183</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64673_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_64673_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64673_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_64673_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64673_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_64673_row3_col1" class="data row3 col1" >(891, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64673_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_64673_row4_col1" class="data row4 col1" >(891, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_64673_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_64673_row5_col1" class="data row5 col1" >(623, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_64673_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_64673_row6_col1" class="data row6 col1" >(268, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_64673_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_64673_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_64673_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_64673_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_64673_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_64673_row9_col1" class="data row9 col1" >79.5%</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_64673_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_64673_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_64673_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_64673_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_64673_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_64673_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_64673_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_64673_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_64673_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_64673_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_64673_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_64673_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_64673_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_64673_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_64673_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_64673_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_64673_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_64673_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_64673_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_64673_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_64673_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_64673_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_64673_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_64673_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_64673_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_64673_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_64673_row22_col1" class="data row22 col1" >3458</td>
#     </tr>
#   </tbody>
# </table>
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:30:35
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_803e9 th {
#   text-align: left;
# }
# #T_803e9_row0_col0, #T_803e9_row0_col1, #T_803e9_row0_col2, #T_803e9_row0_col3, #T_803e9_row0_col4, #T_803e9_row0_col5, #T_803e9_row0_col6, #T_803e9_row0_col7, #T_803e9_row0_col8, #T_803e9_row1_col0, #T_803e9_row1_col1, #T_803e9_row1_col2, #T_803e9_row1_col3, #T_803e9_row1_col4, #T_803e9_row1_col5, #T_803e9_row1_col6, #T_803e9_row1_col7, #T_803e9_row1_col8, #T_803e9_row2_col0, #T_803e9_row2_col1, #T_803e9_row2_col2, #T_803e9_row2_col3, #T_803e9_row2_col4, #T_803e9_row2_col5, #T_803e9_row2_col6, #T_803e9_row2_col7, #T_803e9_row2_col8, #T_803e9_row3_col0, #T_803e9_row3_col1, #T_803e9_row3_col2, #T_803e9_row3_col3, #T_803e9_row3_col4, #T_803e9_row3_col5, #T_803e9_row3_col6, #T_803e9_row3_col7, #T_803e9_row3_col8, #T_803e9_row4_col0, #T_803e9_row4_col1, #T_803e9_row4_col2, #T_803e9_row4_col3, #T_803e9_row4_col4, #T_803e9_row4_col5, #T_803e9_row4_col6, #T_803e9_row4_col7, #T_803e9_row4_col8, #T_803e9_row5_col0, #T_803e9_row5_col1, #T_803e9_row5_col2, #T_803e9_row5_col3, #T_803e9_row5_col4, #T_803e9_row5_col5, #T_803e9_row5_col6, #T_803e9_row5_col7, #T_803e9_row5_col8, #T_803e9_row6_col0, #T_803e9_row6_col1, #T_803e9_row6_col2, #T_803e9_row6_col3, #T_803e9_row6_col4, #T_803e9_row6_col5, #T_803e9_row6_col6, #T_803e9_row6_col7, #T_803e9_row6_col8, #T_803e9_row7_col0, #T_803e9_row7_col1, #T_803e9_row7_col2, #T_803e9_row7_col3, #T_803e9_row7_col4, #T_803e9_row7_col5, #T_803e9_row7_col6, #T_803e9_row7_col7, #T_803e9_row7_col8, #T_803e9_row8_col0, #T_803e9_row8_col1, #T_803e9_row8_col2, #T_803e9_row8_col3, #T_803e9_row8_col4, #T_803e9_row8_col5, #T_803e9_row8_col6, #T_803e9_row8_col7, #T_803e9_row8_col8, #T_803e9_row9_col0, #T_803e9_row9_col1, #T_803e9_row9_col2, #T_803e9_row9_col3, #T_803e9_row9_col4, #T_803e9_row9_col5, #T_803e9_row9_col6, #T_803e9_row9_col7, #T_803e9_row9_col8, #T_803e9_row10_col0, #T_803e9_row10_col1, #T_803e9_row10_col2, #T_803e9_row10_col3, #T_803e9_row10_col4, #T_803e9_row10_col5, #T_803e9_row10_col6, #T_803e9_row10_col7, #T_803e9_row10_col8, #T_803e9_row11_col0, #T_803e9_row11_col1, #T_803e9_row11_col2, #T_803e9_row11_col3, #T_803e9_row11_col4, #T_803e9_row11_col5, #T_803e9_row11_col6, #T_803e9_row11_col7, #T_803e9_row11_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_803e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_803e9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_803e9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_803e9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_803e9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_803e9_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_803e9_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_803e9_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_803e9_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_803e9_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_803e9_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_803e9_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_803e9_row0_col1" class="data row0 col1" >0.8139</td>
#       <td id="T_803e9_row0_col2" class="data row0 col2" >0.8655</td>
#       <td id="T_803e9_row0_col3" class="data row0 col3" >0.6864</td>
#       <td id="T_803e9_row0_col4" class="data row0 col4" >0.8120</td>
#       <td id="T_803e9_row0_col5" class="data row0 col5" >0.7391</td>
#       <td id="T_803e9_row0_col6" class="data row0 col6" >0.5964</td>
#       <td id="T_803e9_row0_col7" class="data row0 col7" >0.6057</td>
#       <td id="T_803e9_row0_col8" class="data row0 col8" >2.0650</td>
#     </tr>
#     <tr>
#       <th id="T_803e9_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_803e9_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_803e9_row1_col1" class="data row1 col1" >0.7415</td>
#       <td id="T_803e9_row1_col2" class="data row1 col2" >0.8634</td>
#       <td id="T_803e9_row1_col3" class="data row1 col3" >0.4221</td>
#       <td id="T_803e9_row1_col4" class="data row1 col4" >0.8140</td>
#       <td id="T_803e9_row1_col5" class="data row1 col5" >0.5490</td>
#       <td id="T_803e9_row1_col6" class="data row1 col6" >0.3961</td>
#       <td id="T_803e9_row1_col7" class="data row1 col7" >0.4400</td>
#       <td id="T_803e9_row1_col8" class="data row1 col8" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_803e9_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_803e9_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_803e9_row2_col1" class="data row2 col1" >0.7286</td>
#       <td id="T_803e9_row2_col2" class="data row2 col2" >0.7877</td>
#       <td id="T_803e9_row2_col3" class="data row2 col3" >0.3757</td>
#       <td id="T_803e9_row2_col4" class="data row2 col4" >0.8739</td>
#       <td id="T_803e9_row2_col5" class="data row2 col5" >0.4913</td>
#       <td id="T_803e9_row2_col6" class="data row2 col6" >0.3547</td>
#       <td id="T_803e9_row2_col7" class="data row2 col7" >0.4264</td>
#       <td id="T_803e9_row2_col8" class="data row2 col8" >0.2460</td>
#     </tr>
#     <tr>
#       <th id="T_803e9_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_803e9_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_803e9_row3_col1" class="data row3 col1" >0.6806</td>
#       <td id="T_803e9_row3_col2" class="data row3 col2" >0.7810</td>
#       <td id="T_803e9_row3_col3" class="data row3 col3" >0.2089</td>
#       <td id="T_803e9_row3_col4" class="data row3 col4" >0.8619</td>
#       <td id="T_803e9_row3_col5" class="data row3 col5" >0.3301</td>
#       <td id="T_803e9_row3_col6" class="data row3 col6" >0.2122</td>
#       <td id="T_803e9_row3_col7" class="data row3 col7" >0.3059</td>
#       <td id="T_803e9_row3_col8" class="data row3 col8" >0.2760</td>
#     </tr>
#     <tr>
#       <th id="T_803e9_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_803e9_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_803e9_row4_col1" class="data row4 col1" >0.6164</td>
#       <td id="T_803e9_row4_col2" class="data row4 col2" >0.5000</td>
#       <td id="T_803e9_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_803e9_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_803e9_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_803e9_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_803e9_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_803e9_row4_col8" class="data row4 col8" >0.2720</td>
#     </tr>
#     <tr>
#       <th id="T_803e9_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_803e9_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_803e9_row5_col1" class="data row5 col1" >0.6164</td>
#       <td id="T_803e9_row5_col2" class="data row5 col2" >0.8226</td>
#       <td id="T_803e9_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_803e9_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_803e9_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_803e9_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_803e9_row5_col7" class="data row5 col7" >0.0000</td>
#       <td id="T_803e9_row5_col8" class="data row5 col8" >0.2380</td>
#     </tr>
#     <tr>
#       <th id="T_803e9_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_803e9_row6_col0" class="data row6 col0" >Ada Boost Classifier</td>
#       <td id="T_803e9_row6_col1" class="data row6 col1" >0.6164</td>
#       <td id="T_803e9_row6_col2" class="data row6 col2" >0.5000</td>
#       <td id="T_803e9_row6_col3" class="data row6 col3" >0.0000</td>
#       <td id="T_803e9_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_803e9_row6_col5" class="data row6 col5" >0.0000</td>
#       <td i
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 20
#      17 grid = setup(data=df, target=df.columns[1],  verbose=True)
#      19 # 모델 학습
# ---> 20 best = compare_models()
#      22 # best 모델 확인
#      23 print(best)
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/pycaret/utils/generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/pycaret/classification/functional.py:814, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#     672 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     673 def compare_models(
#     674     include: Optional[List[Union[str, Any]]] = None,
#    (...)
#     690     parallel: Optional[ParallelBackend] = None,
#     691 ) -> Union[Any, List[Any]]:
#     692     """
#     693     This function trains and evaluates performance of all estimators available in the
#     694     model library using cross validation. The output of this function is a score grid
#    (...)
#     811     - No models are logged in ``MLFlow`` when ``cross_validation`` parameter is False.
#     812     """
# --> 814     return _CURRENT_EXPERIMENT.compare_models(
#     815         include=include,
#     816         exclude=exclude,
#     817         fold=fold,
#     818         round=round,
#     819         cross_validation=cross_validation,
#     820         sort=sort,
#     821         n_select=n_select,
#     822         budget_time=budget_time,
#     823         turbo=turbo,
#     824         errors=errors,
#     825         fit_kwargs=fit_kwargs,
#     826         groups=groups,
#     827         experiment_custom_tags=experiment_custom_tags,
#     828         probability_threshold=probability_threshold,
#     829         engine=engine,
#     830         verbose=verbose,
#     831         parallel=parallel,
#     832     )
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/pycaret/classification/oop.py:1180, in ClassificationExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#    1177         self._set_engine(estimator=estimator, engine=eng, severity="error")
#    1179 try:
# -> 1180     return_values = super().compare_models(
#    1181         include=include,
#    1182         exclude=exclude,
#    1183         fold=fold,
#    1184         round=round,
#    1185         cross_validation=cross_validation,
#    1186         sort=sort,
#    1187         n_select=n_select,
#    1188         budget_time=budget_time,
#    1189         turbo=turbo,
#    1190         errors=errors,
#    1191         fit_kwargs=fit_kwargs,
#    1192         groups=groups,
#    1193         experiment_custom_tags=experiment_custom_tags,
#    1194         verbose=verbose,
#    1195         probability_threshold=probability_threshold,
#    1196         parallel=parallel,
#    1197         caller_params=caller_params,
#    1198     )
#    1199 finally:
#    1200     if engine is not None:
#    1201         # Reset the models back to the default engines
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:794, in _SupervisedExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     791 results_columns_to_ignore = ["Object", "runtime", "cutoff"]
#     793 try:
# --> 794     model, model_fit_time = self._create_model(**create_model_args)
#     795     model_results = self.pull(pop=True)
#     796     assert (
#     797         np.sum(
#     798             model_results.drop(
#    (...)
#     802         != 0.0
#     803     )
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:1533, in _SupervisedExperiment._create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, system, add_to_model_list, X_train_data, y_train_data, metrics, display, model_only, return_train_score, error_score, **kwargs)
#    1530         return model, model_fit_time
#    1531     return model
# -> 1533 model, model_fit_time, model_results, _ = self._create_model_with_cv(
#    1534     model=model,
#    1535     data_X=data_X,
#    1536     data_y=data_y,
#    1537     fit_kwargs=fit_kwargs,
#    1538     round=round,
#    1539     cv=cv,
#    1540     groups=groups,
#    1541     metrics=metrics,
#    1542     refit=refit,
#    1543     system=system,
#    1544     display=display,
#    1545     error_score=error_score,
#    1546     return_train_score=return_train_score,
#    1547 )
#    1549 # end runtime
#    1550 runtime_end = time.time()
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:1126, in _SupervisedExperiment._create_model_with_cv(self, model, data_X, data_y, fit_kwargs, round, cv, groups, metrics, refit, system, display, error_score, return_train_score)
#    1124     model_fit_start = time.time()
#    1125     with redirect_output(self.logger):
# -> 1126         scores = cross_validate(
#    1127             pipeline_with_model,
#    1128             data_X,
#    1129             data_y,
#    1130             cv=cv,
#    1131             groups=groups,
#    1132             scoring=metrics_dict,
#    1133             params=fit_kwargs,
#    1134             n_jobs=n_jobs,
#    1135             return_train_score=return_train_score,
#    1136             error_score=error_score,
#    1137         )
#    1139 model_fit_end = time.time()
#    1140 model_fit_time = np.array(model_fit_end - model_fit_start).round(2)
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:430, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     427 # We clone the estimator to make sure that all the folds are
#     428 # independent, and that it is pickle-able.
#     429 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 430 results = parallel(
#     431     delayed(_fit_and_score)(
#     432         clone(estimator),
#     433         X,
#     434         y,
#     435         scorer=scorers,
#     436         train=train,
#     437         test=test,
#     438         verbose=verbose,
#     439         parameters=None,
#     440         fit_params=routed_params.estimator.fit,
#     441         score_params=routed_params.scorer.score,
#     442         return_train_score=return_train_score,
#     443         return_times=True,
#     444         return_estimator=return_estimator,
#     445         error_score=error_score,
#     446     )
#     447     for train, test in indices
#     448 )
#     450 _warn_or_raise_about_fit_failures(results, error_score)
#     452 # For callable scoring, the return type is only know after calling. If the
#     453 # return type is a dictionary, the error scores can now be inserted with
#     454 # the correct key.
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/anaconda3/envs/autosry/lib/python3.10/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
from pandas import read_csv
# pycaret classification 모듈
from pycaret.classification import setup
# pycaret classification 모델들을 비교하기 위한 모듈
from pycaret.classification import compare_models

# 데이터셋 로드
df = read_csv("titanic.csv")

# 컬럼 갯수
# n_cols = df.shape[1]

# 컬럼명 String으로 반환
# df.columns = [str(i) for i in range(n_cols)]

# 데이터셋 설정
grid = setup(data=df, target=df.columns[1])

# 모델 학습
best = compare_models()

# best 모델 확인
print(best)
# Out:
# <style type="text/css">
# #T_36075_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_36075">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36075_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_36075_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36075_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36075_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_36075_row0_col1" class="data row0 col1" >7800</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_36075_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_36075_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_36075_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_36075_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_36075_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_36075_row3_col1" class="data row3 col1" >(891, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_36075_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_36075_row4_col1" class="data row4 col1" >(891, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_36075_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_36075_row5_col1" class="data row5 col1" >(623, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_36075_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_36075_row6_col1" class="data row6 col1" >(268, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_36075_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_36075_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_36075_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_36075_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_36075_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_36075_row9_col1" class="data row9 col1" >79.5%</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_36075_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_36075_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_36075_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_36075_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_36075_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_36075_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_36075_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_36075_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_36075_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_36075_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_36075_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_36075_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_36075_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_36075_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_36075_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_36075_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_36075_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_36075_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_36075_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_36075_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_36075_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_36075_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_36075_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_36075_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_36075_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_36075_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_36075_row22_col1" class="data row22 col1" >905b</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d55f1 th {
#   text-align: left;
# }
# #T_d55f1_row0_col0, #T_d55f1_row0_col4, #T_d55f1_row1_col0, #T_d55f1_row1_col1, #T_d55f1_row1_col2, #T_d55f1_row1_col3, #T_d55f1_row1_col5, #T_d55f1_row1_col6, #T_d55f1_row1_col7, #T_d55f1_row2_col0, #T_d55f1_row2_col1, #T_d55f1_row2_col2, #T_d55f1_row2_col3, #T_d55f1_row2_col4, #T_d55f1_row2_col5, #T_d55f1_row2_col6, #T_d55f1_row2_col7, #T_d55f1_row3_col0, #T_d55f1_row3_col1, #T_d55f1_row3_col2, #T_d55f1_row3_col3, #T_d55f1_row3_col4, #T_d55f1_row3_col5, #T_d55f1_row3_col6, #T_d55f1_row3_col7, #T_d55f1_row4_col0, #T_d55f1_row4_col1, #T_d55f1_row4_col2, #T_d55f1_row4_col3, #T_d55f1_row4_col4, #T_d55f1_row4_col5, #T_d55f1_row4_col6, #T_d55f1_row4_col7, #T_d55f1_row5_col0, #T_d55f1_row5_col1, #T_d55f1_row5_col2, #T_d55f1_row5_col3, #T_d55f1_row5_col4, #T_d55f1_row5_col5, #T_d55f1_row5_col6, #T_d55f1_row5_col7, #T_d55f1_row6_col0, #T_d55f1_row6_col1, #T_d55f1_row6_col2, #T_d55f1_row6_col3, #T_d55f1_row6_col4, #T_d55f1_row6_col5, #T_d55f1_row6_col6, #T_d55f1_row6_col7, #T_d55f1_row7_col0, #T_d55f1_row7_col1, #T_d55f1_row7_col2, #T_d55f1_row7_col3, #T_d55f1_row7_col4, #T_d55f1_row7_col5, #T_d55f1_row7_col6, #T_d55f1_row7_col7, #T_d55f1_row8_col0, #T_d55f1_row8_col1, #T_d55f1_row8_col2, #T_d55f1_row8_col3, #T_d55f1_row8_col4, #T_d55f1_row8_col5, #T_d55f1_row8_col6, #T_d55f1_row8_col7, #T_d55f1_row9_col0, #T_d55f1_row9_col1, #T_d55f1_row9_col2, #T_d55f1_row9_col3, #T_d55f1_row9_col4, #T_d55f1_row9_col5, #T_d55f1_row9_col6, #T_d55f1_row9_col7, #T_d55f1_row10_col0, #T_d55f1_row10_col1, #T_d55f1_row10_col2, #T_d55f1_row10_col3, #T_d55f1_row10_col4, #T_d55f1_row10_col5, #T_d55f1_row10_col6, #T_d55f1_row10_col7, #T_d55f1_row11_col0, #T_d55f1_row11_col1, #T_d55f1_row11_col2, #T_d55f1_row11_col3, #T_d55f1_row11_col4, #T_d55f1_row11_col5, #T_d55f1_row11_col6, #T_d55f1_row11_col7, #T_d55f1_row12_col0, #T_d55f1_row12_col1, #T_d55f1_row12_col2, #T_d55f1_row12_col3, #T_d55f1_row12_col4, #T_d55f1_row12_col5, #T_d55f1_row12_col6, #T_d55f1_row12_col7, #T_d55f1_row13_col0, #T_d55f1_row13_col1, #T_d55f1_row13_col2, #T_d55f1_row13_col3, #T_d55f1_row13_col4, #T_d55f1_row13_col5, #T_d55f1_row13_col6, #T_d55f1_row13_col7 {
#   text-align: left;
# }
# #T_d55f1_row0_col1, #T_d55f1_row0_col2, #T_d55f1_row0_col3, #T_d55f1_row0_col5, #T_d55f1_row0_col6, #T_d55f1_row0_col7, #T_d55f1_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d55f1_row0_col8, #T_d55f1_row1_col8, #T_d55f1_row2_col8, #T_d55f1_row3_col8, #T_d55f1_row4_col8, #T_d55f1_row5_col8, #T_d55f1_row6_col8, #T_d55f1_row7_col8, #T_d55f1_row8_col8, #T_d55f1_row9_col8, #T_d55f1_row10_col8, #T_d55f1_row11_col8, #T_d55f1_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d55f1_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d55f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d55f1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d55f1_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d55f1_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d55f1_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d55f1_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d55f1_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d55f1_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d55f1_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_d55f1_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d55f1_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_d55f1_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_d55f1_row0_col1" class="data row0 col1" >0.8251</td>
#       <td id="T_d55f1_row0_col2" class="data row0 col2" >0.8757</td>
#       <td id="T_d55f1_row0_col3" class="data row0 col3" >0.7025</td>
#       <td id="T_d55f1_row0_col4" class="data row0 col4" >0.8168</td>
#       <td id="T_d55f1_row0_col5" class="data row0 col5" >0.7540</td>
#       <td id="T_d55f1_row0_col6" class="data row0 col6" >0.6197</td>
#       <td id="T_d55f1_row0_col7" class="data row0 col7" >0.6251</td>
#       <td id="T_d55f1_row0_col8" class="data row0 col8" >1.9140</td>
#     </tr>
#     <tr>
#       <th id="T_d55f1_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_d55f1_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_d55f1_row1_col1" class="data row1 col1" >0.7463</td>
#       <td id="T_d55f1_row1_col2" class="data row1 col2" >0.8524</td>
#       <td id="T_d55f1_row1_col3" class="data row1 col3" >0.4304</td>
#       <td id="T_d55f1_row1_col4" class="data row1 col4" >0.8297</td>
#       <td id="T_d55f1_row1_col5" class="data row1 col5" >0.5616</td>
#       <td id="T_d55f1_row1_col6" class="data row1 col6" >0.4089</td>
#       <td id="T_d55f1_row1_col7" class="data row1 col7" >0.4545</td>
#       <td id="T_d55f1_row1_col8" class="data row1 col8" >0.9280</td>
#     </tr>
#     <tr>
#       <th id="T_d55f1_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_d55f1_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_d55f1_row2_col1" class="data row2 col1" >0.7417</td>
#       <td id="T_d55f1_row2_col2" class="data row2 col2" >0.7981</td>
#       <td id="T_d55f1_row2_col3" class="data row2 col3" >0.4935</td>
#       <td id="T_d55f1_row2_col4" class="data row2 col4" >0.7514</td>
#       <td id="T_d55f1_row2_col5" class="data row2 col5" >0.5902</td>
#       <td id="T_d55f1_row2_col6" class="data row2 col6" >0.4151</td>
#       <td id="T_d55f1_row2_col7" class="data row2 col7" >0.4373</td>
#       <td id="T_d55f1_row2_col8" class="data row2 col8" >1.3110</td>
#     </tr>
#     <tr>
#       <th id="T_d55f1_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_d55f1_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_d55f1_row3_col1" class="data row3 col1" >0.6548</td>
#       <td id="T_d55f1_row3_col2" class="data row3 col2" >0.7824</td>
#       <td id="T_d55f1_row3_col3" class="data row3 col3" >0.1426</td>
#       <td id="T_d55f1_row3_col4" class="data row3 col4" >0.7755</td>
#       <td id="T_d55f1_row3_col5" class="data row3 col5" >0.2340</td>
#       <td id="T_d55f1_row3_col6" class="data row3 col6" >0.1366</td>
#       <td id="T_d55f1_row3_col7" class="data row3 col7" >0.2158</td>
#       <td id="T_d55f1_row3_col8" class="data row3 col8" >0.2490</td>
#     </tr>
#     <tr>
#       <th id="T_d55f1_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_d55f1_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_d55f1_row4_col1" class="data row4 col1" >0.6228</td>
#       <td id="T_d55f1_row4_col2" class="data row4 col2" >0.5250</td>
#       <td id="T_d55f1_row4_col3" class="data row4 col3" >0.0304</td>
#       <td id="T_d55f1_row4_col4" class="data row4 col4" >0.0700</td>
#       <td id="T_d55f1_row4_col5" class="data row4 col5" >0.0424</td>
#       <td id="T_d55f1_row4_col6" class="data row4 col6" >0.0257</td>
#       <td id="T_d55f1_row4_col7" class="data row4 col7" >0.0299</td>
#       <td id="T_d55f1_row4_col8" class="data row4 col8" >0.7080</td>
#     </tr>
#     <tr>
#       <th id="T_d55f1_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_d55f1_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_d55f1_row5_col1" class="data row5 col1" >0.6212</td>
#       <td id="T_d55f1_row5_col2" class="data row5 col2" >0.6076</td>
#       <td id="T_d55f1_row5_col3" class="data row5 col3" >0.3645</td>
#       <td id="T_d55f1_row5_col4" class="data row5 col4" >0.5023</td>
#       <td id="T_d55f1_row5_col5" class="data row5 col5" >0.4173</td>
#       <td id="T_d55f1_row5_col6" class="data row5 col6" >0.1527</td>
#       <td id="T_d55f1_row5_col7" class="data row5 col7" >0.1563</td>
#       <td id="T_d55f1_row5_col8" cl
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=7800, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# # 2) Autogluon

# %%
# AutoML - Autogluon

https://www.kaggle.com/datasets/parisrohan/credit-score-classification

# %%
# !pip install autogluon

# %%
import pandas as pd
# Tabular Data를 다루기 때문에 아래 라이브러리를 호출
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
train_df = pd.read_csv('./train2.csv').iloc[:50,:]
#test_df = pd.read_csv('./test.csv').iloc[:50,:]

# %%
train_df.shape

# %%
# autogluon 학습을 위한 데이터 형태로 변환
train = TabularDataset(train_df.drop(['ID'], axis=1))
#test = TabularDataset(test_df.drop(['ID'], axis=1))

# %%
type(train)

# %%
#학습       # AutoML 객체       credit_score를 맞출것이다. 평가 f1_macro
            # 곧바로 fit으로 train 데이터 학습
predictor = TabularPredictor(label='Credit_Score', eval_metric='f1_macro').fit(train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20250829_040758"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.10.18
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #149~20.04.1-Ubuntu SMP Wed Apr 16 08:29:56 UTC 2025
# CPU Count:          8
# Memory Avail:       11.92 GB / 31.34 GB (38.0%)
# Disk Space Avail:   725.98 GB / 1006.36 GB (72.1%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='extreme' : New in v1.4: Massively better than 'best' on datasets <30000 samples by using new models meta-learned on https://tabarena.ai: TabPFNv2, TabICL, Mitra, and TabM. Absolute best accuracy. Requires a GPU. Recommended 64 GB CPU memory and 32+ GB GPU memory.
# 	presets='best'    : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'    : Strong accuracy with fast inference speed.
# 	presets='good'    : Good accuracy with very fast inference speed.
# 	presets='medium'  : Fast training time, ideal for initial prototyping.
# Using hyperparameters preset: hyperparameters='default'
# Beginning AutoGluon training ...
# AutoGluon will save models to "/home/alpaco/autosry/AutogluonModels/ag-20250829_040758"
# Train Data Rows:    50
# Train Data Columns: 26
# Label Column:       Credit_Score
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['Good', 'Standard']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = Standard, class 0 = Good
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Standard) vs negative (Good) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12202.60 MB
# 	Train Data (Original)  Memory Usage: 0.03 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['Type_of_Loan']
# 			Removing text_ngram feature due to error: '__nlp__'
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])        :  8 | ['Annual_Income', 'Monthly_Inhand_Salary', 'Changed_Credit_Limit', 'Outstanding_Debt', 'Credit_Utilization_Ratio', ...]
# 		('int', [])          : 12 | ['Customer_ID', 'Month', 'Age', 'SSN', 'Num_Bank_Accounts', ...]
# 		('object', [])       :  5 | ['Name', 'Occupation', 'Credit_Mix', 'Payment_of_Min_Amount', 'Payment_Behaviour']
# 		('object', ['text']) :  1 | ['Type_of_Loan']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :  4 | ['Name', 'Occupation', 'Payment_of_Min_Amount', 'Payment_Behaviour']
# 		('category', ['text_as_category'])  :  1 | ['Type_of_Loan']
# 		('float', [])                       :  8 | ['Annual_Income', 'Monthly_Inhand_Salary', 'Changed_Credit_Limit', 'Outstanding_Debt', 'Credit_Utilization_Ratio', ...]
# 		('int', [])                         : 12 | ['Customer_ID', 'Month', 'Age', 'SSN', 'Num_Bank_Accounts', ...]
# 		('int', ['binned', 'text_special']) :  8 | ['Type_of_Loan.char_count', 'Type_of_Loan.word_count', 'Type_of_Loan.capital_ratio', 'Type_of_Loan.lower_ratio', 'Type_of_Loan.special_ratio', ...]
# 		('int', ['bool'])                   :  1 | ['Credit_Mix']
# 	0.2s = Fit runtime
# 	26 features in original data used to generate 34 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.18s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1_macro'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 40, Val Rows: 10
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}],
# 	'XGB': [{}],
# 	'FASTAI': [{}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# Fitting 11 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT ...
# 	Fitting with cpus=1, gpus=0, mem=0.0/11.9 GB
# 	0.375	 = Validation score   (f1_macro)
# 	0.84s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ...
# 	Fitting with cpus=1, gpus=0, mem=0.0/11.9 GB
# 	0.375	 = Validation score   (f1_macro)
# 	0.7s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	Fitting with cpus=8, gpus=0
# 	1.0	 = Validation score   (f1_macro)
# 	0.73s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	Fitting with cpus=8, gpus=0
# 	1.0	 = Validation score   (f1_macro)
# 	0.71s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost ...
# 	Fitting with cpus=1, gpus=0
# 	1.0	 = Validation score   (f1_macro)
# 	8.39s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	Fitting with cpus=8, gpus=0
# 	1.0	 = Validation score   (f1_macro)
# 	0.72s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	Fitting with cpus=8, gpus=0
# 	1.0	 = Validation score   (f1_macro)
# 	0.64s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	Fitting with cpus=1, gpus=0, mem=0.0/11.8 GB
# No improvement since epoch 3: early stopping
# 	1.0	 = Validation score   (f1_macro)
# 	2.97s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	Fitting with cpus=1, gpus=0
# 	1.0	 = Validation score   (f1_macro)
# 	0.81s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	Fitting with cpus=1, gpus=0, mem=0.0/11.5 GB
# 	Warning: Exception caused NeuralNetTorch to fail during training... Skipping this model.
# 		ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/alpaco/anaconda3/envs/autosry/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2171, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/home/alpaco/anaconda3/envs/autosry/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2055, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/alpaco/anaconda3/envs/autosry/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#   File "/home/alpaco/anaconda3/envs/autosry/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 214, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#   File "/home/alpaco/anaconda3/envs/autosry/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 692, in _generate_dataset
#     dataset = self._process_train_data(
#   File "/home/alpaco/anaconda3/envs/autosry/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 754, in _process_train_data
#     self.processor = create_preprocessor(
#   File "/home/alpaco/anaconda3/envs/autosry/lib/python3.10/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Fitting model: LightGBMLarge ...
# 	Fitting with cpus=1, gpus=0, mem=0.0/11.5 GB
# 	1.0	 = Validation score   (f1_macro)
# 	0.84s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'XGBoost': 1.0}
# 	1.0	 = Validation score   (f1_macro)
# 	0.25s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 18.45s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 612.7 rows/s (10 batch size)
# Disabling decision threshold calibration for metric `f1_macro` due to having fewer than 50 rows of validation data for calibration to avoid overfitting (10 rows). Force calibration via specifying `calibrate_decision_threshold=True`.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/home/alpaco/autosry/AutogluonModels/ag-20250829_040758")

# %%
# 각각의 모델의 훈련 성능을 평가할 수 있음
ld_board = predictor.leaderboard(train, silent=True)

ld_board
# Out:
#                   model  score_test  score_val eval_metric  pred_time_test  \
# 0              CatBoost    1.000000      1.000    f1_macro        0.013519
# 1        ExtraTreesEntr    1.000000      1.000    f1_macro        0.055930
# 2        ExtraTreesGini    1.000000      1.000    f1_macro        0.056281
# 3      RandomForestEntr    1.000000      1.000    f1_macro        0.057568
# 4      RandomForestGini    1.000000      1.000    f1_macro        0.060023
# 5         LightGBMLarge    0.937991      1.000    f1_macro        0.004070
# 6               XGBoost    0.872666      1.000    f1_macro        0.012771
# 7   WeightedEnsemble_L2    0.872666      1.000    f1_macro        0.014330
# 8       NeuralNetFastAI    0.872666      1.000    f1_macro        0.024799
# 9              LightGBM    0.358974      0.375    f1_macro        0.003211
# 10           LightGBMXT    0.358974      0.375    f1_macro        0.004435
#
#     pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0        0.006597  8.386375                 0.013519                0.006597
# 1        0.049036  0.638980                 0.055930                0.049036
# 2        0.038059  0.715060                 0.056281                0.038059
# 3        0.061503  0.712144                 0.057568                0.061503
# 4        0.050023  0.726552                 0.060023                0.050023
# 5        0.003533  0.836320                 0.004070                0.003533
# 6        0.014201  0.812257                 0.012771                0.014201
# 7        0.016321  1.062599                 0.001559                0.002120
# 8        0.012758  2.974533                 0.024799                0.012758
# 9        0.003587  0.695570                 0.003211                0.003587
# 10       0.004079  0.842936                 0.004435                0.004079
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            8.386375            1       True          5
# 1            0.638980            1       True          7
# 2            0.715060            1       True          6
# 3            0.712144            1       True          4
# 4            0.726552            1       True          3
# 5            0.836320            1       True         10
# 6            0.812257            1       True          9
# 7            0.250342            2       True         11
# 8            2.974533            1       True          8
# 9            0.695570            1       True          2
# 10           0.842936            1       True          1

# %%
from sklearn.metrics import accuracy_score, f1_score
# 예측하기
pred_y = predictor.predict(train)
pred_y
# Out:
# 0         Good
# 1         Good
# 2         Good
# 3         Good
# 4         Good
# 5         Good
# 6         Good
# 7         Good
# 8         Good
# 9         Good
# 10        Good
# 11        Good
# 12        Good
# 13        Good
# 14        Good
# 15        Good
# 16        Good
# 17        Good
# 18        Good
# 19        Good
# 20        Good
# 21        Good
# 22        Good
# 23        Good
# 24    Standard
# 25    Standard
# 26    Standard
# 27    Standard
# 28    Standard
# 29    Standard
# 30    Standard
# 31    Standard
# 32    Standard
# 33    Standard
# 34    Standard
# 35    Standard
# 36    Standard
# 37    Standard
# 38    Standard
# 39    Standard
# 40        Good
# 41        Good
# 42        Good
# 43        Good
# 44        Good
# 45        Good
# 46        Good
# 47        Good
# 48        Good
# 49        Good
# Name: Credit_Score, dtype: object

# %%
accuracy_score(pred_y,train['Credit_Score'])
# Out:
# 0.88
