# %% [markdown]
# 1. 코드로 다운로드 받기
# 2. GPU 연결
# 3. Data.yaml (train/val) path 절대경로로 바꿔주고, model.train(data='/content/fitstproject-2/data.yaml') 로 설정하기

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 67.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 98.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Y8AiE0Db0LkhTrFFcwRk")
project = rf.workspace("mask-detection-joxzn").project("fitstproject-ptqih")
version = project.version(2)
dataset = version.download("yolov12")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to fitstproject-2 in yolov12:: 100%|██████████| 93/93 [00:00<00:00, 6070.19it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo12s.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
model.train(data='/content/fitstproject-2/data.yaml')
# Out:
# Ultralytics 8.3.192 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# results_dict:  'metrics/mAP50(B)': 0.7650925925925925, 'metrics/mAP50-95(B)': 0.40645794291799126,

# %%
from ultralytics import YOLO
model = YOLO("/content/runs/detect/train/weights/best.pt")

model.predict("/content/fitstproject-2/valid/images/-3_jpg.rf.9e0fad26cf3351977ca6274addef0d75.jpg", save=True)
# Out:
# image 1/1 /content/fitstproject-2/valid/images/-3_jpg.rf.9e0fad26cf3351977ca6274addef0d75.jpg: 640x640 2 foots, 5 hands, 1 head, 20.9ms
# Speed: 1.6ms preprocess, 20.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'foot', 1: 'hand', 2: 'head'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
# ...

# %%
#key-point 객체인식 
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train2/weights/best.pt")

model.predict("/img_절대경로.jpg", save=True)

# %%
from ultralytics import YOLO

model = YOLO("yolo8s-pose.pt")

# %%
result = model.predict("/content/사람전신2.jpg")

# %%
result.keypoints # 14개의 관절 좌표를 보여준다

# %%
result[0].plot()
